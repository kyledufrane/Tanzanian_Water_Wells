# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.class_weight import  compute_sample_weight
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score

from xgboost import XGBClassifier

from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
train_df = pd.read_csv('data/ml_training.txt', index_col=[0])
test_df = pd.read_csv('data/ml_testing.txt', index_col=[0])

# %%
df_corr=train_df.corr().abs().stack().reset_index().sort_values(0, ascending=False)
df_corr['pairs'] = list(zip(df_corr.level_0, df_corr.level_1))
df_corr.set_index(['pairs'], inplace = True)
df_corr.drop(columns=['level_1', 'level_0'], inplace = True)
df_corr.columns = ['cc']
df_corr.drop_duplicates(inplace=True)
df_corr = df_corr[df_corr['cc'] < 1.0000]
df_corr.head(10)
# Out:
#                                                           cc
# pairs
# (source_class_non_functional, source_class_func...  0.997228
# (extraction_type_group_functional, extraction_t...  0.997188
# (quantity_non_functional, quantity_group_functi...  0.996439
# (quantity_group_functional, quantity_group_non_...  0.996439
# (waterpoint_type_group_non_functional, waterpoi...  0.996435
# (quality_group_non_functional, quality_group_fu...  0.996039
# (water_quality_functional, quality_group_functi...  0.995305
# (extraction_type_group_non_functional, extracti...  0.995145
# (waterpoint_type_non_functional, waterpoint_typ...  0.994970
# (water_quality_functional, quality_group_non_fu...  0.991363

# %%
corr_feats = set()
corr = df_.corr()

for i in range(len(corr.columns)):
    for j in range(i):
        if abs(corr.iloc[i, j]) > 0.85:
            colname = corr.columns[i]
            corr_feats.add(colname)

# %%
df_ = df_.drop(corr_feats, axis=1)
test_df = test_df.drop(corr_feats, axis=1)

# %%
unwanted_cols = ['date_recorded', 'recorded_by', 'wpt_name', 'Unnamed: 0.1', 'id']
df_.drop(unwanted_cols, axis=1, inplace=True)
test_df.drop(unwanted_cols, axis=1, inplace=True)

# %%
df_.drop('index', axis=1, inplace=True)

# %%
cols = [col for col in df_.columns.tolist() if col != 'status_group']

test_df = test_df.reindex(columns=[col for col in df_.columns]).drop('status_group', axis=1)

test_df.columns.tolist() == cols

# %%
X = train_df.drop(['status_group', 'id'], axis=1).select_dtypes(['int', 'float'])
y = train_df['status_group']

sample_weights = compute_sample_weight('balanced', y)

le = LabelEncoder()
y = le.fit_transform(y)

X_train_, X_test_, y_train_, y_test_ = train_test_split(X,y, random_state=42, stratify=y)
X_val, X_test_, y_val, y_test_ = train_test_split(X_test_, y_test_, random_state=42, stratify=y_test_)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_)
X_test = scaler.transform(X_test_)

rf = RandomForestClassifier(random_state=42, n_jobs=-1)

rf.fit(X_train, y_train_)
y_hat_train = rf.predict(X_train)
y_hat = rf.predict(X_test)

print('Train Accuracy Score:', accuracy_score(y_hat_train, y_train_))
print('Test Accuracy Score:', accuracy_score(y_test_, y_hat))
# Out:
# Train Accuracy Score: 0.9994612794612795
# Test Accuracy Score: 0.834365741987611

# %%
X_train_
# Out:
#          amount_tsh   gps_height  longitude      latitude  num_private  \
# 32062     27.634856   927.475118  35.891117 -6.292893e+00            0
# 13545   4000.000000   937.000000  36.016881 -7.286883e+00            0
# 57464   3124.988836  1283.673823  32.975596 -3.730475e+00            0
# 28328    108.010342   930.199419   0.000000 -2.000000e-08            0
# 18040  12000.000000  1027.000000  35.326772 -9.877166e+00            0
# ...             ...          ...        ...           ...          ...
# 23875    440.844038  2231.144161  33.638030 -9.355884e+00            0
# 39128     25.000000  1512.000000  31.048300 -7.520390e+00            0
# 39454    600.000000   789.000000  29.740101 -4.890159e+00            0
# 5809      20.000000  1553.000000  37.065571 -3.051792e+00            0
# 50484   2996.509264  1249.431119  32.281023 -3.780471e+00            0
#
#         population  well_age  funder_functional  \
# 32062   676.520000        22           0.834341
# 13545   407.243013        32           0.550064
# 57464   668.600054        22           0.457460
# 28328   453.385992        22           0.657143
# 18040  1400.000000        20           0.792683
# ...            ...       ...                ...
# 23875    93.983571        22           0.544930
# 39128   277.893343        29           0.219048
# 39454   210.000000        19           0.250000
# 5809    170.941685        11           0.977654
# 50484   420.829862        22           0.587599
#
#        funder_functional_needs_repair  funder_non_functional  ...  \
# 32062                        0.022975               0.142684  ...
# 13545                        0.051027               0.398909  ...
# 57464                        0.277435               0.265105  ...
# 28328                        0.057143               0.285714  ...
# 18040                        0.024390               0.182927  ...
# ...                               ...                    ...  ...
# 23875                        0.120088               0.334982  ...
# 39128                        0.019048               0.761905  ...
# 39454                        0.450000               0.300000  ...
# 5809                         0.011173               0.011173  ...
# 50484                        0.079308               0.333093  ...
#
#        source_type_non_functional  source_class_functional  \
# 32062                    0.462131                 0.542320
# 13545                    0.302744                 0.542320
# 57464                    0.448348                 0.542320
# 28328                    0.259259                 0.545168
# 18040                    0.338923                 0.545168
# ...                           ...                      ...
# 23875                    0.338923                 0.545168
# 39128                    0.448348                 0.542320
# 39454                    0.448348                 0.542320
# 5809                     0.302744                 0.542320
# 50484                    0.448348                 0.542320
#
#        source_class_functional_needs_repair  source_class_non_functional  \
# 32062                              0.059855                     0.397825
# 13545                              0.059855                     0.397825
# 57464                              0.059855                     0.397825
# 28328                              0.117872                     0.336960
# 18040                              0.117872                     0.336960
# ...                                     ...                          ...
# 23875                              0.117872                     0.336960
# 39128                              0.059855                     0.397825
# 39454                              0.059855                     0.397825
# 5809                               0.059855                     0.397825
# 50484                              0.059855                     0.397825
#
#        waterpoint_type_functional  waterpoint_type_functional_needs_repair  \
# 32062                    0.366213                                 0.106177
# 13545                    0.621485                                 0.079237
# 57464                    0.617852                                 0.058840
# 28328                    0.621485                                 0.079237
# 18040                    0.621485                                 0.079237
# ...                           ...                                      ...
# 23875                    0.621485                                 0.079237
# 39128                    0.131661                                 0.045925
# 39454                    0.131661                                 0.045925
# 5809                     0.621485                                 0.079237
# 50484                    0.617852                                 0.058840
#
#        waterpoint_type_non_functional  waterpoint_type_group_functional  \
# 32062                        0.527609                          0.576491
# 13545                        0.299278                          0.576491
# 57464                        0.323307                          0.617852
# 28328                        0.299278                          0.576491
# 18040                        0.299278                          0.576491
# ...                               ...                               ...
# 23875                        0.299278                          0.576491
# 39128                        0.822414                          0.131661
# 39454                        0.822414                          0.131661
# 5809                         0.299278                          0.576491
# 50484                        0.323307                          0.617852
#
#        waterpoint_type_group_functional_needs_repair  \
# 32062                                       0.083986
# 13545                                       0.083986
# 57464                                       0.058840
# 28328                                       0.083986
# 18040                                       0.083986
# ...                                              ...
# 23875                                       0.083986
# 39128                                       0.045925
# 39454                                       0.045925
# 5809                                        0.083986
# 50484                                       0.058840
#
#        waterpoint_type_group_non_functional
# 32062                              0.339523
# 13545                              0.339523
# 57464                              0.323307
# 28328                              0.339523
# 18040                              0.339523
# ...                                     ...
# 23875                              0.339523
# 39128                              0.822414
# 39454                              0.822414
# 5809                               0.339523
# 50484                              0.323307
#
# [44550 rows x 94 columns]

# %%
xgb = XGBClassifier(use_label_encoder=False, \
                    n_jobs=-1,
                    tree_method='gpu_hist',
                    objective='multi:softprob',
                    sample_weight=sample_weights)

watchlist = [(X_train_, y_train_), (X_val, y_val)]

xgb.fit(X_train_, y_train_, eval_set=watchlist, eval_metric='merror')

y_hat = xgb.predict(X_test_)
print('Train Accuracy score:', accuracy_score(y_hat_train, y_train_))
# print('Accuracy score:', accuracy_score(y_test, y_hat))
print('Test Accuracy Score:', accuracy_score(y_test_, y_hat))
# Out:
# [11:08:42] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117836726/work/src/learner.cc:576:
# Parameters: { "sample_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-merror:0.19917	validation_1-merror:0.19664
# [1]	validation_0-merror:0.19109	validation_1-merror:0.19098
# [2]	validation_0-merror:0.18857	validation_1-merror:0.18820
# [3]	validation_0-merror:0.18727	validation_1-merror:0.18793
# [4]	validation_0-merror:0.18274	validation_1-merror:0.18434
# /home/kyle/anaconda3/envs/xgboost/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [5]	validation_0-merror:0.18063	validation_1-merror:0.18281
# [6]	validation_0-merror:0.17973	validation_1-merror:0.18326
# [7]	validation_0-merror:0.17863	validation_1-merror:0.18219
# [8]	validation_0-merror:0.17690	validation_1-merror:0.18012
# [9]	validation_0-merror:0.17571	validation_1-merror:0.17904
# [10]	validation_0-merror:0.17421	validation_1-merror:0.17824
# [11]	validation_0-merror:0.17394	validation_1-merror:0.17698
# [12]	validation_0-merror:0.17347	validation_1-merror:0.17590
# [13]	validation_0-merror:0.17138	validation_1-merror:0.17339
# [14]	validation_0-merror:0.17012	validation_1-merror:0.17249
# [15]	validation_0-merror:0.16992	validation_1-merror:0.17222
# [16]	validation_0-merror:0.16945	validation_1-merror:0.17024
# [17]	validation_0-merror:0.16772	validation_1-merror:0.16934
# [18]	validation_0-merror:0.16700	validation_1-merror:0.16908
# [19]	validation_0-merror:0.16678	validation_1-merror:0.16908
# [20]	validation_0-merror:0.16541	validation_1-merror:0.16782
# [21]	validation_0-merror:0.16274	validation_1-merror:0.16692
# [22]	validation_0-merror:0.16220	validation_1-merror:0.16593
# [23]	validation_0-merror:0.16115	validation_1-merror:0.16647
# [24]	validation_0-merror:0.16018	validation_1-merror:0.16665
# [25]	validation_0-merror:0.15962	validation_1-merror:0.16512
# [26]	validation_0-merror:0.15919	validation_1-merror:0.16432
# [27]	validation_0-merror:0.15852	validation_1-merror:0.16396
# [28]	validation_0-merror:0.15820	validation_1-merror:0.16387
# [29]	validation_0-merror:0.15722	validation_1-merror:0.16261
# [30]	validation_0-merror:0.15659	validation_1-merror:0.16207
# [31]	validation_0-merror:0.15625	validation_1-merror:0.16207
# [32]	validation_0-merror:0.15587	validation_1-merror:0.16198
# [33]	validation_0-merror:0.15371	validation_1-merror:0.16180
# [34]	validation_0-merror:0.15235	validation_1-merror:0.16144
# [35]	validation_0-merror:0.15219	validation_1-merror:0.16135
# [36]	validation_0-merror:0.15172	validation_1-merror:0.16090
# [37]	validation_0-merror:0.15143	validation_1-merror:0.16064
# [38]	validation_0-merror:0.15062	validation_1-merror:0.16028
# [39]	validation_0-merror:0.15026	validation_1-merror:0.16028
# [40]	validation_0-merror:0.15001	validation_1-merror:0.15992
# [41]	validation_0-merror:0.14882	validation_1-merror:0.15911
# [42]	validation_0-merror:0.14858	validation_1-merror:0.15911
# [43]	validation_0-merror:0.14837	validation_1-merror:0.15884
# [44]	validation_0-merror:0.14703	validation_1-merror:0.15947
# [45]	validation_0-merror:0.14649	validation_1-merror:0.15848
# [46]	validation_0-merror:0.14602	validation_1-merror:0.15839
# [47]	validation_0-merror:0.14492	validation_1-merror:0.15884
# [48]	validation_0-merror:0.14433	validation_1-merror:0.15821
# [49]	validation_0-merror:0.14379	validation_1-merror:0.15812
# [50]	validation_0-merror:0.14321	validation_1-merror:0.15911
# [51]	validation_0-merror:0.14254	validation_1-merror:0.15911
# [52]	validation_0-merror:0.14240	validation_1-merror:0.15893
# [53]	validation_0-merror:0.14206	validation_1-merror:0.15884
# [54]	validation_0-merror:0.14092	validation_1-merror:0.15893
# [55]	validation_0-merror:0.14018	validation_1-merror:0.15839
# [56]	validation_0-merror:0.13973	validation_1-merror:0.15794
# [57]	validation_0-merror:0.13930	validation_1-merror:0.15785
# [58]	validation_0-merror:0.13908	validation_1-merror:0.15821
# [59]	validation_0-merror:0.13794	validation_1-merror:0.15785
# [60]	validation_0-merror:0.13722	validation_1-merror:0.15866
# [61]	validation_0-merror:0.13677	validation_1-merror:0.15920
# [62]	validation_0-merror:0.13609	validation_1-merror:0.15965
# [63]	validation_0-merror:0.13544	validation_1-merror:0.15974
# [64]	validation_0-merror:0.13392	validation_1-merror:0.15956
# [65]	validation_0-merror:0.13362	validation_1-merror:0.15947
# [66]	validation_0-merror:0.13313	validation_1-merror:0.15965
# [67]	validation_0-merror:0.13255	validation_1-merror:0.15893
# [68]	validation_0-merror:0.13194	validation_1-merror:0.15920
# [69]	validation_0-merror:0.13089	validation_1-merror:0.15974
# [70]	validation_0-merror:0.13032	validation_1-merror:0.16019
# [71]	validation_0-merror:0.12961	validation_1-merror:0.15992
# [72]	validation_0-merror:0.12920	validation_1-merror:0.16010
# [73]	validation_0-merror:0.12842	validation_1-merror:0.16019
# [74]	validation_0-merror:0.12837	validation_1-merror:0.16055
# [75]	validation_0-merror:0.12732	validation_1-merror:0.16073
# [76]	validation_0-merror:0.12687	validation_1-merror:0.16082
# [77]	validation_0-merror:0.12671	validation_1-merror:0.16064
# [78]	validation_0-merror:0.12646	validation_1-merror:0.16028
# [79]	validation_0-merror:0.12557	validation_1-merror:0.15992
# [80]	validation_0-merror:0.12518	validation_1-merror:0.15920
# [81]	validation_0-merror:0.12505	validation_1-merror:0.15947
# [82]	validation_0-merror:0.12429	validation_1-merror:0.15983
# [83]	validation_0-merror:0.12409	validation_1-merror:0.15956
# [84]	validation_0-merror:0.12326	validation_1-merror:0.15938
# [85]	validation_0-merror:0.12287	validation_1-merror:0.15938
# [86]	validation_0-merror:0.12231	validation_1-merror:0.15992
# [87]	validation_0-merror:0.12117	validation_1-merror:0.15929
# [88]	validation_0-merror:0.12065	validation_1-merror:0.15929
# [89]	validation_0-merror:0.11980	validation_1-merror:0.15911
# [90]	validation_0-merror:0.11939	validation_1-merror:0.15956
# [91]	validation_0-merror:0.11935	validation_1-merror:0.15938
# [92]	validation_0-merror:0.11876	validation_1-merror:0.15911
# [93]	validation_0-merror:0.11818	validation_1-merror:0.15929
# [94]	validation_0-merror:0.11728	validation_1-merror:0.15929
# [95]	validation_0-merror:0.11675	validation_1-merror:0.15938
# [96]	validation_0-merror:0.11576	validation_1-merror:0.15974
# [97]	validation_0-merror:0.11499	validation_1-merror:0.15902
# [98]	validation_0-merror:0.11448	validation_1-merror:0.15929
# [99]	validation_0-merror:0.11371	validation_1-merror:0.15866
# Train Accuracy score: 0.9994612794612795
# Test Accuracy Score: 0.8502558577969297

# %%
def score(params):
    print("Training with params: ")
    print(params)
    watchlist = [(X_train_, y_train_), (X_val, y_val)]
    gbm_model = XGBClassifier(
        use_label_encoder=False,
        n_estimators = int(params['n_estimators']),
        max_depth= params['max_depth'],
        min_child_weight= params['min_child_weight'],
        subsample= params['subsample'],
        gamma= params['gamma'],
        colsample_bytree= params['colsample_bytree'],
        eta= params['eta'],
        eval_metric= 'merror',
        objective= 'multi:softprob',
        tree_method='gpu_hist',
        booster= 'gbtree',
        silent= 1,
        seed= 42,
        # num_class= 3,
        sample_weight=sample_weights
    )
    gbm_model.fit(X_train_, y_train_,
                  eval_set=watchlist)
    predictions = gbm_model.predict(X_test_)

    score_ = cross_val_score(gbm_model, X_train_, y_train_, cv=5, scoring='accuracy', n_jobs=-1).mean()

    print("\tScore {0}\n\n".format(score_))

    return {'loss': -score_, 'status': STATUS_OK}


def optimize(trials):
    """
    This is the optimization function that given a space (space here) of
    hyperparameters and a scoring function (score here), finds the best hyperparameters.
    """

    space = {
        'n_estimators': hp.quniform('n_estimators', 10, 1000, 1),
        'eta': hp.quniform('eta', 0.025, 0.5, 0.025),
        'max_depth':  hp.choice('max_depth', np.arange(1, 20, dtype=int)),
        'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
        'subsample': hp.quniform('subsample', 0.5, 1, 0.05),
        'gamma': hp.quniform('gamma', 0.5, 1, 0.05),
        'colsample_bytree': hp.quniform('colsample_bytree', 0.5, 1, 0.05),
    }
    # Use the fmin function from Hyperopt to find the best hyperparameters
    best = fmin(score, \
                space, \
                algo=tpe.suggest, \
                trials=trials, \
                max_evals=100)
    return best

trials = Trials()

best_hyperparams = optimize(trials)
# Out:
# Training with params:
# {'colsample_bytree': 0.8500000000000001, 'eta': 0.30000000000000004, 'gamma': 0.8500000000000001, 'max_depth': 16, 'min_child_weight': 4.0, 'n_estimators': 164.0, 'subsample': 0.65}
# [11:10:25] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117836726/work/src/learner.cc:576:
# Parameters: { "sample_weight", "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# /home/kyle/anaconda3/envs/xgboost/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-merror:0.14909	validation_1-merror:0.18416
# [1]	validation_0-merror:0.13645	validation_1-merror:0.17824
# [2]	validation_0-merror:0.13008	validation_1-merror:0.17464
# [3]	validation_0-merror:0.12563	validation_1-merror:0.17231
# [4]	validation_0-merror:0.12274	validation_1-merror:0.17069
# [5]	validation_0-merror:0.11924	validation_1-merror:0.16854
# [6]	validation_0-merror:0.11612	validation_1-merror:0.16611
# [7]	validation_0-merror:0.11432	validation_1-merror:0.16620
# [8]	validation_0-merror:0.11253	validation_1-merror:0.16441
# [9]	validation_0-merror:0.11041	validation_1-merror:0.16432
# [10]	validation_0-merror:0.10813	validation_1-merror:0.16288
# [11]	validation_0-merror:0.10622	validation_1-merror:0.16378
# [12]	validation_0-merror:0.10453	validation_1-merror:0.16279
# [13]	validation_0-merror:0.10328	validation_1-merror:0.16297
# [14]	validation_0-merror:0.10189	validation_1-merror:0.16414
# [15]	validation_0-merror:0.10121	validation_1-merror:0.16360
# [16]	validation_0-merror:0.09847	validation_1-merror:0.16297
# [17]	validation_0-merror:0.09641	validation_1-merror:0.16252
# [18]	validation_0-merror:0.09495	validation_1-merror:0.16234
# [19]	validation_0-merror:0.09280	validation_1-merror:0.16369
# [20]	validation_0-merror:0.09131	validation_1-merror:0.16261
# [21]	validation_0-merror:0.09006	validation_1-merror:0.16252
# [22]	validation_0-merror:0.08774	validation_1-merror:0.16279
# [23]	validation_0-merror:0.08528	validation_1-merror:0.16387
# [24]	validation_0-merror:0.08350	validation_1-merror:0.16477
# [25]	validation_0-merror:0.08130	validation_1-merror:0.16531
# [26]	validation_0-merror:0.07984	validation_1-merror:0.16539
# [27]	validation_0-merror:0.07764	validation_1-merror:0.16665
# [28]	validation_0-merror:0.07565	validation_1-merror:0.16638
# [29]	validation_0-merror:0.07365	validation_1-merror:0.16863
# [30]	validation_0-merror:0.07151	validation_1-merror:0.16818
# [31]	validation_0-merror:0.06992	validation_1-merror:0.16800
# [32]	validation_0-merror:0.06896	validation_1-merror:0.16836
# [33]	validation_0-merror:0.06734	validation_1-merror:0.16890
# [34]	validation_0-merror:0.06642	validation_1-merror:0.16818
# [35]	validation_0-merror:0.06527	validation_1-merror:0.16872
# [36]	validation_0-merror:0.06541	validation_1-merror:0.16845
# [37]	validation_0-merror:0.06496	validation_1-merror:0.16872
# [38]	validation_0-merror:0.06321	validation_1-merror:0.16970
# [39]	validation_0-merror:0.06265	validation_1-merror:0.16890
# [40]	validation_0-merror:0.06247	validation_1-merror:0.16827
# [41]	validation_0-merror:0.06200	validation_1-merror:0.16908
# [42]	validation_0-merror:0.06141	validation_1-merror:0.16934
# [43]	validation_0-merror:0.06117	validation_1-merror:0.16953
# [44]	validation_0-merror:0.06079	validation_1-merror:0.16970
# [45]	validation_0-merror:0.06022	validation_1-merror:0.16988
# [46]	validation_0-merror:0.05962	validation_1-merror:0.16953
# [47]	validation_0-merror:0.05820	validation_1-merror:0.16872
# [48]	validation_0-merror:0.05753	validation_1-merror:0.16934
# [49]	validation_0-merror:0.05746	validation_1-merror:0.16970
# [50]	validation_0-merror:0.05702	validation_1-merror:0.16934
# [51]	validation_0-merror:0.05665	validation_1-merror:0.16953
# [52]	validation_0-merror:0.05614	validation_1-merror:0.16934
# [53]	validation_0-merror:0.05596	validation_1-merror:0.16872
# [54]	validation_0-merror:0.05567	validation_1-merror:0.16854
# [55]	validation_0-merror:0.05491	validation_1-merror:0.16791
# [56]	validation_0-merror:0.05396	validation_1-merror:0.16773
# [57]	validation_0-merror:0.05358	validation_1-merror:0.16881
# [58]	validation_0-merror:0.05342	validation_1-merror:0.16899
# [59]	validation_0-merror:0.05353	validation_1-merror:0.16934
# [60]	validation_0-merror:0.05311	validation_1-merror:0.16899
# [61]	validation_0-merror:0.05338	validation_1-merror:0.16863
# [62]	validation_0-merror:0.05362	validation_1-merror:0.16970
# [63]	validation_0-merror:0.05365	validation_1-merror:0.16961
# [64]	validation_0-merror:0.05322	validation_1-merror:0.16934
# [65]	validation_0-merror:0.05277	validation_1-merror:0.16997
# [66]	validation_0-merror:0.05284	validation_1-merror:0.17006
# [67]	validation_0-merror:0.05221	validation_1-merror:0.17042
# [68]	validation_0-merror:0.05228	validation_1-merror:0.16988
# [69]	validation_0-merror:0.05172	validation_1-merror:0.16961
# [70]	validation_0-merror:0.05158	validation_1-merror:0.16988
# [71]	validation_0-merror:0.05149	validation_1-merror:0.16979
# [72]	validation_0-merror:0.05145	validation_1-merror:0.17024
# [73]	validation_0-merror:0.05127	validation_1-merror:0.16988
# [74]	validation_0-merror:0.05109	validation_1-merror:0.17033
# [75]	validation_0-merror:0.05091	validation_1-merror:0.17087
# [76]	validation_0-merror:0.05046	validation_1-merror:0.17078
# [77]	validation_0-merror:0.05033	validation_1-merror:0.17186
# [78]	validation_0-merror:0.05033	validation_1-merror:0.17195
# [79]	validation_0-merror:0.05028	validation_1-merror:0.17168
# [80]	validation_0-merror:0.04990	validation_1-merror:0.17123
# [81]	validation_0-merror:0.04994	validation_1-merror:0.17177
# [82]	validation_0-merror:0.04974	validation_1-merror:0.17177
# [83]	validation_0-merror:0.04961	validation_1-merror:0.17231
# [84]	validation_0-merror:0.04893	validation_1-merror:0.17213
# [85]	validation_0-merror:0.04862	validation_1-merror:0.17168
# [86]	validation_0-merror:0.04873	validation_1-merror:0.17150
# [87]	validation_0-merror:0.04844	validation_1-merror:0.17195
# [88]	validation_0-merror:0.04844	validation_1-merror:0.17204
# [89]	validation_0-merror:0.04873	validation_1-merror:0.17177
# [90]	validation_0-merror:0.04840	validation_1-merror:0.17213
# [91]	validation_0-merror:0.04842	validation_1-merror:0.17204
# [92]	validation_0-merror:0.04858	validation_1-merror:0.17168
# [93]	validation_0-merror:0.04840	validation_1-merror:0.17132
# [94]	validation_0-merror:0.04781	validation_1-merror:0.17177
# [95]	validation_0-merror:0.04763	validation_1-merror:0.17168
# [96]	validation_0-merror:0.04759	validation_1-merror:0.17168
# [97]	validation_0-merror:0.04761	validation_1-merror:0.17105
# [98]	validation_0-merror:0.04759	validation_1-merror:0.17159
# [99]	validation_0-merror:0.04748	validation_1-merror:0.17195
# [100]	validation_0-merror:0.04736	validation_1-merror:0.17159
# [101]	validation_0-merror:0.04770	validation_1-merror:0.17204
# [102]	validation_0-merror:0.04743	validation_1-merror:0.17186
# [103]	validation_0-merror:0.04718	validation_1-merror:0.17177
# [104]	validation_0-merror:0.04718	validation_1-merror:0.17168
# [105]	validation_0-merror:0.04723	validation_1-merror:0.17168
# [106]	validation_0-merror:0.04718	validation_1-merror:0.17141
# [107]	validation_0-merror:0.04725	validation_1-merror:0.17159
# [108]	validation_0-merror:0.04716	validation_1-merror:0.17132
# [109]	validation_0-merror:0.04700	validation_1-merror:0.17159
# [110]	validation_0-merror:0.04707	validation_1-merror:0.17105
# [111]	validation_0-merror:0.04673	validation_1-merror:0.17123
# [112]	validation_0-merror:0.04671	validation_1-merror:0.17150
# [113]	validation_0-merror:0.04651	validation_1-merror:0.17123
# [114]	validation_0-merror:0.04680	validation_1-merror:0.17114
# [115]	validation_0-merror:0.04649	validation_1-merror:0.17159
# [116]	validation_0-merror:0.04631	validation_1-merror:0.17186
# [117]	validation_0-merror:0.04644	validation_1-merror:0.17213
# [118]	validation_0-merror:0.04637	validation_1-merror:0.17303
# [119]	validation_0-merror:0.04626	validation_1-merror:0.17285
# [120]	validation_0-merror:0.04619	validation_1-merror:0.17285
# [121]	validation_0-merror:0.04615	validation_1-merror:0.17267
# [122]	validation_0-merror:0.04590	validation_1-merror:0.17321
# [123]	validation_0-merror:0.04595	validation_1-merror:0.17294
# [124]	validation_0-merror:0.04604	validation_1-merror:0.17303
# [125]	validation_0-merror:0.04602	validation_1-merror:0.17294
# [126]	validation_0-merror:0.04606	validation_1-merror:0.17303
# [127]	validation_0-merror:0.04597	validation_1-merror:0.17348
# [128]	validation_0-merror:0.04554	validation_1-merror:0.17285
# [129]	validation_0-merror:0.04537	validation_1-merror:0.17312
# [130]	validation_0-merror:0.04537	validation_1-merror:0.17366
# [131]	validation_0-merror:0.04563	validation_1-merror:0.17312
# [132]	validation_0-merror:0.04543	validation_1-merror:0.17339
# [133]	validation_0-merror:0.04534	validation_1-merror:0.17366
# [134]	validation_0-merror:0.04539	validation_1-merror:0.17375
# [135]	validation_0-merror:0.04514	validation_1-merror:0.17366
# [136]	validation_0-merror:0.04471	validation_1-merror:0.17375
# [137]	validation_0-merror:0.04485	validation_1-merror:0.17330
# [138]	validation_0-merror:0.04483	validation_1-merror:0.17366
# [139]	validation_0-merror:0.04489	validation_1-merror:0.17375
# [140]	validation_0-merror:0.04462	validation_1-merror:0.17383
# [141]	validation_0-merror:0.04469	validation_1-merror:0.17383
# [142]	validation_0-merror:0.04471	validation_1-merror:0.17366
# [143]	validation_0-merror:0.04451	validation_1-merror:0.17348
# [144]	validation_0-merror:0.04451	validation_1-merror:0.17366
# [145]	validation_0-merror:0.04444	validation_1-merror:0.17366
# [146]	validation_0-merror:0.04456	validation_1-merror:0.17375
# [147]	validation_0-merror:0.04413	validation_1-merror:0.17366
# [148]	validation_0-merror:0.04426	validation_1-merror:0.17312
# [149]	validation_0-merror:0.04424	validation_1-merror:0.17375
# [150]	validation_0-merror:0.04429	validation_1-merror:0.17285
# [151]	validation_0-merror:0.04422	validation_1-merror:0.17276
# [152]	validation_0-merror:0.04417	validation_1-merror:0.17294
# [153]	validation_0-merror:0.04388	validation_1-merror:0.17383
# [154]	validation_0-merror:0.04364	validation_1-merror:0.17383
# [155]	validation_0-merror:0.04386	validation_1-merror:0.17383
# [156]	validation_0-merror:0.04386	validation_1-merror:0.17383
# [157]	validation_0-merror:0.04379	validation_1-merror:0.17366
# [158]	validation_0-merror:0.04379	validation_1-merror:0.17392
# [159]	validation_0-merror:0.04375	validation_1-merror:0.17375
# [160]	validation_0-merror:0.04364	validation_1-merror:0.17402
# [161]	validation_0-merror:0.04357	validation_1-merror:0.17348
# [162]	validation_0-merror:0.04359	validation_1-merror:0.17402
# [163]	validation_0-merror:0.04350	validation_1-merror:0.17446
# 	Score 0.8234792368125703
#
#
# Training with params:
# {'colsample_bytree': 0.8500000000000001, 'eta': 0.17500000000000002, 'gamma': 0.65, 'max_depth': 2, 'min_child_weight': 2.0, 'n_estimators': 689.0, 'subsample': 0.7000000000000001}
# [11:10:56] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117836726/work/src/learner.cc:576:
# Parameters: { "sample_weight", "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-merror:0.31674	validation_1-merror:0.32136
# [1]	validation_0-merror:0.25560	validation_1-merror:0.25258
# [2]	validation_0-merror:0.23560	validation_1-merror:0.23498
# [3]	validation_0-merror:0.23508	validation_1-merror:0.23265
# [4]	validation_0-merror:0.23131	validation_1-merror:0.22888
# [5]	validation_0-merror:0.23127	validation_1-merror:0.22834
# [6]	validation_0-merror:0.22595	validation_1-merror:0.22277
# [7]	validation_0-merror:0.22343	validation_1-merror:0.22017
# [8]	validation_0-merror:0.21834	validation_1-merror:0.21254
# [9]	validation_0-merror:0.21809	validation_1-merror:0.21128
# [10]	validation_0-merror:0.21446	validation_1-merror:0.20634
# [11]	validation_0-merror:0.21268	validation_1-merror:0.20598
# [12]	validation_0-merror:0.20788	validation_1-merror:0.20194
# [13]	validation_0-merror:0.20633	validation_1-merror:0.20176
# [14]	validation_0-merror:0.20366	validation_1-merror:0.19916
# [15]	validation_0-merror:0.20283	validation_1-merror:0.19844
# [16]	validation_0-merror:0.20298	validation_1-merror:0.19907
# [17]	validation_0-merror:0.20231	validation_1-merror:0.19826
#   1%|          | 1/100 [00:30<50:08, 30.38s/trial, best loss: -0.8234792368125703]
# /home/kyle/anaconda3/envs/xgboost/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [18]	validation_0-merror:0.20123	validation_1-merror:0.19682
# [19]	validation_0-merror:0.19883	validation_1-merror:0.19503
# [20]	validation_0-merror:0.19769	validation_1-merror:0.19386
# [21]	validation_0-merror:0.19740	validation_1-merror:0.19314
# [22]	validation_0-merror:0.19681	validation_1-merror:0.19287
# [23]	validation_0-merror:0.19665	validation_1-merror:0.19242
# [24]	validation_0-merror:0.19587	validation_1-merror:0.19170
# [25]	validation_0-merror:0.19513	validation_1-merror:0.19152
# [26]	validation_0-merror:0.19432	validation_1-merror:0.19054
# [27]	validation_0-merror:0.19412	validation_1-merror:0.19054
# [28]	validation_0-merror:0.19376	validation_1-merror:0.18955
# [29]	validation_0-merror:0.19282	validation_1-merror:0.18964
# [30]	validation_0-merror:0.19230	validation_1-merror:0.18874
# [31]	validation_0-merror:0.19181	validation_1-merror:0.18847
# [32]	validation_0-merror:0.19127	validation_1-merror:0.18793
# [33]	validation_0-merror:0.19107	validation_1-merror:0.18748
# [34]	validation_0-merror:0.19026	validation_1-merror:0.18784
# [35]	validation_0-merror:0.18976	validation_1-merror:0.18685
# [36]	validation_0-merror:0.18934	validation_1-merror:0.18739
# [37]	validation_0-merror:0.18963	validation_1-merror:0.18685
# [38]	validation_0-merror:0.18875	validation_1-merror:0.18623
# [39]	validation_0-merror:0.18855	validation_1-merror:0.18587
# [40]	validation_0-merror:0.18846	validation_1-merror:0.18578
# [41]	validation_0-merror:0.18806	validation_1-merror:0.18542
# [42]	validation_0-merror:0.18741	validation_1-merror:0.18524
# [43]	validation_0-merror:0.18729	validation_1-merror:0.18443
# [44]	validation_0-merror:0.18678	validation_1-merror:0.18452
# [45]	validation_0-merror:0.18615	validation_1-merror:0.18407
# [46]	validation_0-merror:0.18577	validation_1-merror:0.18335
# [47]	validation_0-merror:0.18575	validation_1-merror:0.18344
# [48]	validation_0-merror:0.18561	validation_1-merror:0.18299
# [49]	validation_0-merror:0.18525	validation_1-merror:0.18255
# [50]	validation_0-merror:0.18516	validation_1-merror:0.18246
# [51]	validation_0-merror:0.18467	validation_1-merror:0.18156
# [52]	validation_0-merror:0.18413	validation_1-merror:0.18192
# [53]	validation_0-merror:0.18368	validation_1-merror:0.18120
# [54]	validation_0-merror:0.18330	validation_1-merror:0.18075
# [55]	validation_0-merror:0.18307	validation_1-merror:0.18057
# [56]	validation_0-merror:0.18312	validation_1-merror:0.17994
# [57]	validation_0-merror:0.18276	validation_1-merror:0.18003
# [58]	validation_0-merror:0.18263	validation_1-merror:0.17994
# [59]	validation_0-merror:0.18231	validation_1-merror:0.17958
# [60]	validation_0-merror:0.18218	validation_1-merror:0.17931
# [61]	validation_0-merror:0.18191	validation_1-merror:0.17833
# [62]	validation_0-merror:0.18186	validation_1-merror:0.17814
# [63]	validation_0-merror:0.18148	validation_1-merror:0.17752
# [64]	validation_0-merror:0.18094	validation_1-merror:0.17779
# [65]	validation_0-merror:0.18090	validation_1-merror:0.17716
# [66]	validation_0-merror:0.18090	validation_1-merror:0.17725
# [67]	validation_0-merror:0.18067	validation_1-merror:0.17707
# [68]	validation_0-merror:0.18013	validation_1-merror:0.17689
# [69]	validation_0-merror:0.18011	validation_1-merror:0.17689
# [70]	validation_0-merror:0.18000	validation_1-merror:0.17707
# [71]	validation_0-merror:0.17986	validation_1-merror:0.17662
# [72]	validation_0-merror:0.17964	validation_1-merror:0.17644
# [73]	validation_0-merror:0.17960	validation_1-merror:0.17599
# [74]	validation_0-merror:0.17969	validation_1-merror:0.17608
# [75]	validation_0-merror:0.17948	validation_1-merror:0.17590
# [76]	validation_0-merror:0.17879	validation_1-merror:0.17446
# [77]	validation_0-merror:0.17863	validation_1-merror:0.17464
# [78]	validation_0-merror:0.17845	validation_1-merror:0.17491
# [79]	validation_0-merror:0.17850	validation_1-merror:0.17545
# [80]	validation_0-merror:0.17850	validation_1-merror:0.17527
# [81]	validation_0-merror:0.17850	validation_1-merror:0.17545
# [82]	validation_0-merror:0.17847	validation_1-merror:0.17473
# [83]	validation_0-merror:0.17836	validation_1-merror:0.17509
# [84]	validation_0-merror:0.17789	validation_1-merror:0.17464
# [85]	validation_0-merror:0.17787	validation_1-merror:0.17527
# [86]	validation_0-merror:0.17787	validation_1-merror:0.17527
# [87]	validation_0-merror:0.17742	validation_1-merror:0.17410
# [88]	validation_0-merror:0.17758	validation_1-merror:0.17410
# [89]	validation_0-merror:0.17713	validation_1-merror:0.17392
# [90]	validation_0-merror:0.17724	validation_1-merror:0.17366
# [91]	validation_0-merror:0.17681	validation_1-merror:0.17339
# [92]	validation_0-merror:0.17704	validation_1-merror:0.17258
# [93]	validation_0-merror:0.17683	validation_1-merror:0.17303
# [94]	validation_0-merror:0.17670	validation_1-merror:0.17240
# [95]	validation_0-merror:0.17659	validation_1-merror:0.17204
# [96]	validation_0-merror:0.17609	validation_1-merror:0.17231
# [97]	validation_0-merror:0.17627	validation_1-merror:0.17240
# [98]	validation_0-merror:0.17578	validation_1-merror:0.17150
# [99]	validation_0-merror:0.17567	validation_1-merror:0.17150
# [100]	validation_0-merror:0.17556	validation_1-merror:0.17150
# [101]	validation_0-merror:0.17538	validation_1-merror:0.17015
# [102]	validation_0-merror:0.17558	validation_1-merror:0.17024
# [103]	validation_0-merror:0.17535	validation_1-merror:0.16988
# [104]	validation_0-merror:0.17515	validation_1-merror:0.16979
# [105]	validation_0-merror:0.17511	validation_1-merror:0.16970
# [106]	validation_0-merror:0.17457	validation_1-merror:0.16979
# [107]	validation_0-merror:0.17477	validation_1-merror:0.16961
# [108]	validation_0-merror:0.17450	validation_1-merror:0.16953
# [109]	validation_0-merror:0.17446	validation_1-merror:0.16953
# [110]	validation_0-merror:0.17432	validation_1-merror:0.16944
# [111]	validation_0-merror:0.17396	validation_1-merror:0.16926
# [112]	validation_0-merror:0.17392	validation_1-merror:0.16934
# [113]	validation_0-merror:0.17416	validation_1-merror:0.16997
# [114]	validation_0-merror:0.17396	validation_1-merror:0.16979
# [115]	validation_0-merror:0.17389	validation_1-merror:0.16997
# [116]	validation_0-merror:0.17374	validation_1-merror:0.16988
# [117]	validation_0-merror:0.17318	validation_1-merror:0.16970
# [118]	validation_0-merror:0.17302	validation_1-merror:0.16872
# [119]	validation_0-merror:0.17293	validation_1-merror:0.16917
# [120]	validation_0-merror:0.17255	validation_1-merror:0.16917
# [121]	validation_0-merror:0.17244	validation_1-merror:0.16863
# [122]	validation_0-merror:0.17237	validation_1-merror:0.16845
# [123]	validation_0-merror:0.17241	validation_1-merror:0.16854
# [124]	validation_0-merror:0.17226	validation_1-merror:0.16827
# [125]	validation_0-merror:0.17201	validation_1-merror:0.16845
# [126]	validation_0-merror:0.17190	validation_1-merror:0.16854
# [127]	validation_0-merror:0.17183	validation_1-merror:0.16800
# [128]	validation_0-merror:0.17190	validation_1-merror:0.16863
# [129]	validation_0-merror:0.17167	validation_1-merror:0.16836
# [130]	validation_0-merror:0.17138	validation_1-merror:0.16854
# [131]	validation_0-merror:0.17127	validation_1-merror:0.16908
# [132]	validation_0-merror:0.17127	validation_1-merror:0.16890
# [133]	validation_0-merror:0.17131	validation_1-merror:0.16881
# [134]	validation_0-merror:0.17118	validation_1-merror:0.16899
# [135]	validation_0-merror:0.17109	validation_1-merror:0.16881
# [136]	validation_0-merror:0.17120	validation_1-merror:0.16934
# [137]	validation_0-merror:0.17084	validation_1-merror:0.16944
# [138]	validation_0-merror:0.17100	validation_1-merror:0.16917
# [139]	validation_0-merror:0.17104	validation_1-merror:0.16934
# [140]	validation_0-merror:0.17080	validation_1-merror:0.16979
# [141]	validation_0-merror:0.17080	validation_1-merror:0.16961
# [142]	validation_0-merror:0.17071	validation_1-merror:0.16953
# [143]	validation_0-merror:0.17053	validation_1-merror:0.16926
# [144]	validation_0-merror:0.17039	validation_1-merror:0.16872
# [145]	validation_0-merror:0.17039	validation_1-merror:0.16899
# [146]	validation_0-merror:0.16997	validation_1-merror:0.16926
# [147]	validation_0-merror:0.16997	validation_1-merror:0.16908
# [148]	validation_0-merror:0.16976	validation_1-merror:0.16908
# [149]	validation_0-merror:0.16985	validation_1-merror:0.16908
# [150]	validation_0-merror:0.16965	validation_1-merror:0.16845
# [151]	validation_0-merror:0.16938	validation_1-merror:0.16827
# [152]	validation_0-merror:0.16927	validation_1-merror:0.16809
# [153]	validation_0-merror:0.16945	validation_1-merror:0.16800
# [154]	validation_0-merror:0.16967	validation_1-merror:0.16773
# [155]	validation_0-merror:0.16967	validation_1-merror:0.16809
# [156]	validation_0-merror:0.16974	validation_1-merror:0.16872
# [157]	validation_0-merror:0.16961	validation_1-merror:0.16800
# [158]	validation_0-merror:0.16950	validation_1-merror:0.16746
# [159]	validation_0-merror:0.16938	validation_1-merror:0.16818
# [160]	validation_0-merror:0.16902	validation_1-merror:0.16782
# [161]	validation_0-merror:0.16893	validation_1-merror:0.16782
# [162]	validation_0-merror:0.16891	validation_1-merror:0.16737
# [163]	validation_0-merror:0.16882	validation_1-merror:0.16728
# [164]	validation_0-merror:0.16882	validation_1-merror:0.16764
# [165]	validation_0-merror:0.16853	validation_1-merror:0.16782
# [166]	validation_0-merror:0.16862	validation_1-merror:0.16782
# [167]	validation_0-merror:0.16839	validation_1-merror:0.16728
# [168]	validation_0-merror:0.16831	validation_1-merror:0.16710
# [169]	validation_0-merror:0.16810	validation_1-merror:0.16728
# [170]	validation_0-merror:0.16828	validation_1-merror:0.16701
# [171]	validation_0-merror:0.16806	validation_1-merror:0.16755
# [172]	validation_0-merror:0.16804	validation_1-merror:0.16764
# [173]	validation_0-merror:0.16799	validation_1-merror:0.16746
# [174]	validation_0-merror:0.16788	validation_1-merror:0.16755
# [175]	validation_0-merror:0.16795	validation_1-merror:0.16764
# [176]	validation_0-merror:0.16768	validation_1-merror:0.16755
# [177]	validation_0-merror:0.16739	validation_1-merror:0.16800
# [178]	validation_0-merror:0.16736	validation_1-merror:0.16800
# [179]	validation_0-merror:0.16729	validation_1-merror:0.16782
# [180]	validation_0-merror:0.16725	validation_1-merror:0.16773
# [181]	validation_0-merror:0.16707	validation_1-merror:0.16728
# [182]	validation_0-merror:0.16716	validation_1-merror:0.16737
# [183]	validation_0-merror:0.16725	validation_1-merror:0.16719
# [184]	validation_0-merror:0.16720	validation_1-merror:0.16701
# [185]	validation_0-merror:0.16741	validation_1-merror:0.16701
# [186]	validation_0-merror:0.16718	validation_1-merror:0.16665
# [187]	validation_0-merror:0.16703	validation_1-merror:0.16629
# [188]	validation_0-merror:0.16689	validation_1-merror:0.16629
# [189]	validation_0-merror:0.16658	validation_1-merror:0.16611
# [190]	validation_0-merror:0.16678	validation_1-merror:0.16638
# [191]	validation_0-merror:0.16658	validation_1-merror:0.16665
# [192]	validation_0-merror:0.16649	validation_1-merror:0.16674
# [193]	validation_0-merror:0.16631	validation_1-merror:0.16638
# [194]	validation_0-merror:0.16647	validation_1-merror:0.16629
# [195]	validation_0-merror:0.16615	validation_1-merror:0.16674
# [196]	validation_0-merror:0.16559	validation_1-merror:0.16647
# [197]	validation_0-merror:0.16552	validation_1-merror:0.16665
# [198]	validation_0-merror:0.16581	validation_1-merror:0.16647
# [199]	validation_0-merror:0.16559	validation_1-merror:0.16683
# [200]	validation_0-merror:0.16552	validation_1-merror:0.16665
# [201]	validation_0-merror:0.16557	validation_1-merror:0.16629
# [202]	validation_0-merror:0.16541	validation_1-merror:0.16620
# [203]	validation_0-merror:0.16539	validation_1-merror:0.16647
# [204]	validation_0-merror:0.16545	validation_1-merror:0.16656
# [205]	validation_0-merror:0.16550	validation_1-merror:0.16647
# [206]	validation_0-merror:0.16554	validation_1-merror:0.16665
# [207]	validation_0-merror:0.16568	validation_1-merror:0.16719
# [208]	validation_0-merror:0.16539	validation_1-merror:0.16719
# [209]	validation_0-merror:0.16514	validation_1-merror:0.16701
# [210]	validation_0-merror:0.16509	validation_1-merror:0.16692
# [211]	validation_0-merror:0.16498	validation_1-merror:0.16719
# [212]	validation_0-merror:0.16507	validation_1-merror:0.16719
# [213]	validation_0-merror:0.16496	validation_1-merror:0.16710
# [214]	validation_0-merror:0.16516	validation_1-merror:0.16773
# [215]	validation_0-merror:0.16514	validation_1-merror:0.16746
# [216]	validation_0-merror:0.16480	validation_1-merror:0.16692
# [217]	validation_0-merror:0.16476	validation_1-merror:0.16692
# [218]	validation_0-merror:0.16494	validation_1-merror:0.16656
# [219]	validation_0-merror:0.16480	validation_1-merror:0.16674
# [220]	validation_0-merror:0.16492	validation_1-merror:0.16692
# [221]	validation_0-merror:0.16471	validation_1-merror:0.16674
# [222]	validation_0-merror:0.16469	validation_1-merror:0.16665
# [223]	validation_0-merror:0.16476	validation_1-merror:0.16665
# [224]	validation_0-merror:0.16465	validation_1-merror:0.16629
# [225]	validation_0-merror:0.16474	validation_1-merror:0.16620
# [226]	validation_0-merror:0.16456	validation_1-merror:0.16656
# [227]	validation_0-merror:0.16467	validation_1-merror:0.16656
# [228]	validation_0-merror:0.16449	validation_1-merror:0.16647
# [229]	validation_0-merror:0.16447	validation_1-merror:0.16629
# [230]	validation_0-merror:0.16436	validation_1-merror:0.16647
# [231]	validation_0-merror:0.16431	validation_1-merror:0.16665
# [232]	validation_0-merror:0.16426	validation_1-merror:0.16629
# [233]	validation_0-merror:0.16438	validation_1-merror:0.16629
# [234]	validation_0-merror:0.16404	validation_1-merror:0.16629
# [235]	validation_0-merror:0.16406	validation_1-merror:0.16620
# [236]	validation_0-merror:0.16420	validation_1-merror:0.16620
# [237]	validation_0-merror:0.16411	validation_1-merror:0.16647
# [238]	validation_0-merror:0.16400	validation_1-merror:0.16629
# [239]	validation_0-merror:0.16393	validation_1-merror:0.16647
# [240]	validation_0-merror:0.16397	validation_1-merror:0.16638
# [241]	validation_0-merror:0.16368	validation_1-merror:0.16620
# [242]	validation_0-merror:0.16355	validation_1-merror:0.16602
# [243]	validation_0-merror:0.16346	validation_1-merror:0.16629
# [244]	validation_0-merror:0.16326	validation_1-merror:0.16611
# [245]	validation_0-merror:0.16332	validation_1-merror:0.16611
# [246]	validation_0-merror:0.16334	validation_1-merror:0.16629
# [247]	validation_0-merror:0.16330	validation_1-merror:0.16611
# [248]	validation_0-merror:0.16330	validation_1-merror:0.16638
# [249]	validation_0-merror:0.16321	validation_1-merror:0.16620
# [250]	validation_0-merror:0.16314	validation_1-merror:0.16629
# [251]	validation_0-merror:0.16301	validation_1-merror:0.16638
# [252]	validation_0-merror:0.16274	validation_1-merror:0.16611
# [253]	validation_0-merror:0.16278	validation_1-merror:0.16602
# [254]	validation_0-merror:0.16269	validation_1-merror:0.16548
# [255]	validation_0-merror:0.16283	validation_1-merror:0.16575
# [256]	validation_0-merror:0.16267	validation_1-merror:0.16548
# [257]	validation_0-merror:0.16269	validation_1-merror:0.16522
# [258]	validation_0-merror:0.16256	validation_1-merror:0.16522
# [259]	validation_0-merror:0.16278	validation_1-merror:0.16468
# [260]	validation_0-merror:0.16240	validation_1-merror:0.16495
# [261]	validation_0-merror:0.16254	validation_1-merror:0.16503
# [262]	validation_0-merror:0.16256	validation_1-merror:0.16486
# [263]	validation_0-merror:0.16245	validation_1-merror:0.16522
# [264]	validation_0-merror:0.16240	validation_1-merror:0.16495
# [265]	validation_0-merror:0.16233	validation_1-merror:0.16531
# [266]	validation_0-merror:0.16218	validation_1-merror:0.16557
# [267]	validation_0-merror:0.16215	validation_1-merror:0.16575
# [268]	validation_0-merror:0.16209	validation_1-merror:0.16566
# [269]	validation_0-merror:0.16195	validation_1-merror:0.16557
# [270]	validation_0-merror:0.16202	validation_1-merror:0.16575
# [271]	validation_0-merror:0.16184	validation_1-merror:0.16575
# [272]	validation_0-merror:0.16182	validation_1-merror:0.16522
# [273]	validation_0-merror:0.16186	validation_1-merror:0.16512
# [274]	validation_0-merror:0.16193	validation_1-merror:0.16486
# [275]	validation_0-merror:0.16175	validation_1-merror:0.16495
# [276]	validation_0-merror:0.16182	validation_1-merror:0.16486
# [277]	validation_0-merror:0.16164	validation_1-merror:0.16503
# [278]	validation_0-merror:0.16157	validation_1-merror:0.16503
# [279]	validation_0-merror:0.16141	validation_1-merror:0.16512
# [280]	validation_0-merror:0.16157	validation_1-merror:0.16477
# [281]	validation_0-merror:0.16148	validation_1-merror:0.16432
# [282]	validation_0-merror:0.16135	validation_1-merror:0.16387
# [283]	validation_0-merror:0.16130	validation_1-merror:0.16432
# [284]	validation_0-merror:0.16139	validation_1-merror:0.16396
# [285]	validation_0-merror:0.16135	validation_1-merror:0.16405
# [286]	validation_0-merror:0.16150	validation_1-merror:0.16441
# [287]	validation_0-merror:0.16130	validation_1-merror:0.16405
# [288]	validation_0-merror:0.16121	validation_1-merror:0.16387
# [289]	validation_0-merror:0.16110	validation_1-merror:0.16405
# [290]	validation_0-merror:0.16144	validation_1-merror:0.16396
# [291]	validation_0-merror:0.16135	validation_1-merror:0.16423
# [292]	validation_0-merror:0.16117	validation_1-merror:0.16378
# [293]	validation_0-merror:0.16126	validation_1-merror:0.16360
# [294]	validation_0-merror:0.16123	validation_1-merror:0.16360
# [295]	validation_0-merror:0.16128	validation_1-merror:0.16378
# [296]	validation_0-merror:0.16101	validation_1-merror:0.16396
# [297]	validation_0-merror:0.16099	validation_1-merror:0.16414
# [298]	validation_0-merror:0.16117	validation_1-merror:0.16387
# [299]	validation_0-merror:0.16108	validation_1-merror:0.16405
# [300]	validation_0-merror:0.16096	validation_1-merror:0.16360
# [301]	validation_0-merror:0.16099	validation_1-merror:0.16360
# [302]	validation_0-merror:0.16115	validation_1-merror:0.16333
# [303]	validation_0-merror:0.16083	validation_1-merror:0.16324
# [304]	validation_0-merror:0.16083	validation_1-merror:0.16306
# [305]	validation_0-merror:0.16083	validation_1-merror:0.16306
# [306]	validation_0-merror:0.16079	validation_1-merror:0.16306
# [307]	validation_0-merror:0.16085	validation_1-merror:0.16279
# [308]	validation_0-merror:0.16065	validation_1-merror:0.16279
# [309]	validation_0-merror:0.16085	validation_1-merror:0.16225
# [310]	validation_0-merror:0.16067	validation_1-merror:0.16261
# [311]	validation_0-merror:0.16056	validation_1-merror:0.16306
# [312]	validation_0-merror:0.16047	validation_1-merror:0.16333
# [313]	validation_0-merror:0.16045	validation_1-merror:0.16306
# [314]	validation_0-merror:0.16034	validation_1-merror:0.16261
# [315]	validation_0-merror:0.16045	validation_1-merror:0.16306
# [316]	validation_0-merror:0.16040	validation_1-merror:0.16270
# [317]	validation_0-merror:0.16027	validation_1-merror:0.16324
# [318]	validation_0-merror:0.16013	validation_1-merror:0.16351
# [319]	validation_0-merror:0.16020	validation_1-merror:0.16333
# [320]	validation_0-merror:0.16020	validation_1-merror:0.16279
# [321]	validation_0-merror:0.16013	validation_1-merror:0.16306
# [322]	validation_0-merror:0.16016	validation_1-merror:0.16324
# [323]	validation_0-merror:0.16007	validation_1-merror:0.16297
# [324]	validation_0-merror:0.15998	validation_1-merror:0.16333
# [325]	validation_0-merror:0.16002	validation_1-merror:0.16324
# [326]	validation_0-merror:0.15982	validation_1-merror:0.16324
# [327]	validation_0-merror:0.15973	validation_1-merror:0.16315
# [328]	validation_0-merror:0.15984	validation_1-merror:0.16369
# [329]	validation_0-merror:0.15975	validation_1-merror:0.16333
# [330]	validation_0-merror:0.15991	validation_1-merror:0.16378
# [331]	validation_0-merror:0.15951	validation_1-merror:0.16306
# [332]	validation_0-merror:0.15946	validation_1-merror:0.16324
# [333]	validation_0-merror:0.15935	validation_1-merror:0.16324
# [334]	validation_0-merror:0.15924	validation_1-merror:0.16324
# [335]	validation_0-merror:0.15924	validation_1-merror:0.16342
# [336]	validation_0-merror:0.15906	validation_1-merror:0.16342
# [337]	validation_0-merror:0.15906	validation_1-merror:0.16351
# [338]	validation_0-merror:0.15885	validation_1-merror:0.16324
# [339]	validation_0-merror:0.15890	validation_1-merror:0.16333
# [340]	validation_0-merror:0.15890	validation_1-merror:0.16297
# [341]	validation_0-merror:0.15897	validation_1-merror:0.16360
# [342]	validation_0-merror:0.15888	validation_1-merror:0.16297
# [343]	validation_0-merror:0.15881	validation_1-merror:0.16297
# [344]	validation_0-merror:0.15850	validation_1-merror:0.16252
# [345]	validation_0-merror:0.15850	validation_1-merror:0.16252
# [346]	validation_0-merror:0.15856	validation_1-merror:0.16252
# [347]	validation_0-merror:0.15872	validation_1-merror:0.16243
# [348]	validation_0-merror:0.15847	validation_1-merror:0.16243
# [349]	validation_0-merror:0.15859	validation_1-merror:0.16243
# [350]	validation_0-merror:0.15854	validation_1-merror:0.16252
# [351]	validation_0-merror:0.15841	validation_1-merror:0.16225
# [352]	validation_0-merror:0.15841	validation_1-merror:0.16270
# [353]	validation_0-merror:0.15852	validation_1-merror:0.16207
# [354]	validation_0-merror:0.15838	validation_1-merror:0.16162
# [355]	validation_0-merror:0.15838	validation_1-merror:0.16243
# [356]	validation_0-merror:0.15814	validation_1-merror:0.16153
# [357]	validation_0-merror:0.15805	validation_1-merror:0.16198
# [358]	validation_0-merror:0.15809	validation_1-merror:0.16198
# [359]	validation_0-merror:0.15789	validation_1-merror:0.16162
# [360]	validation_0-merror:0.15789	validation_1-merror:0.16144
# [361]	validation_0-merror:0.15805	validation_1-merror:0.16198
# [362]	validation_0-merror:0.15805	validation_1-merror:0.16207
# [363]	validation_0-merror:0.15787	validation_1-merror:0.16180
# [364]	validation_0-merror:0.15787	validation_1-merror:0.16171
# [365]	validation_0-merror:0.15767	validation_1-merror:0.16162
# [366]	validation_0-merror:0.15776	validation_1-merror:0.16171
# [367]	validation_0-merror:0.15778	validation_1-merror:0.16171
# [368]	validation_0-merror:0.15773	validation_1-merror:0.16180
# [369]	validation_0-merror:0.15760	validation_1-merror:0.16189
# [370]	validation_0-merror:0.15771	validation_1-merror:0.16153
# [371]	validation_0-merror:0.15728	validation_1-merror:0.16171
# [372]	validation_0-merror:0.15744	validation_1-merror:0.16153
# [373]	validation_0-merror:0.15746	validation_1-merror:0.16144
# [374]	validation_0-merror:0.15746	validation_1-merror:0.16162
# [375]	validation_0-merror:0.15753	validation_1-merror:0.16189
# [376]	validation_0-merror:0.15724	validation_1-merror:0.16153
# [377]	validation_0-merror:0.15728	validation_1-merror:0.16153
# [378]	validation_0-merror:0.15726	validation_1-merror:0.16162
# [379]	validation_0-merror:0.15742	validation_1-merror:0.16153
# [380]	validation_0-merror:0.15731	validation_1-merror:0.16189
# [381]	validation_0-merror:0.15724	validation_1-merror:0.16153
# [382]	validation_0-merror:0.15713	validation_1-merror:0.16153
# [383]	validation_0-merror:0.15722	validation_1-merror:0.16144
# [384]	validation_0-merror:0.15724	validation_1-merror:0.16126
# [385]	validation_0-merror:0.15722	validation_1-merror:0.16153
# [386]	validation_0-merror:0.15724	validation_1-merror:0.16144
# [387]	validation_0-merror:0.15690	validation_1-merror:0.16099
# [388]	validation_0-merror:0.15677	validation_1-merror:0.16117
# [389]	validation_0-merror:0.15674	validation_1-merror:0.16162
# [390]	validation_0-merror:0.15710	validation_1-merror:0.16117
# [391]	validation_0-merror:0.15706	validation_1-merror:0.16126
# [392]	validation_0-merror:0.15704	validation_1-merror:0.16099
# [393]	validation_0-merror:0.15710	validation_1-merror:0.16126
# [394]	validation_0-merror:0.15693	validation_1-merror:0.16109
# [395]	validation_0-merror:0.15695	validation_1-merror:0.16099
# [396]	validation_0-merror:0.15679	validation_1-merror:0.16090
# [397]	validation_0-merror:0.15659	validation_1-merror:0.16109
# [398]	validation_0-merror:0.15636	validation_1-merror:0.16082
# [399]	validation_0-merror:0.15641	validation_1-merror:0.16055
# [400]	validation_0-merror:0.15645	validation_1-merror:0.16090
# [401]	validation_0-merror:0.15650	validation_1-merror:0.16117
# [402]	validation_0-merror:0.15677	validation_1-merror:0.16162
# [403]	validation_0-merror:0.15684	validation_1-merror:0.16180
# [404]	validation_0-merror:0.15654	validation_1-merror:0.16126
# [405]	validation_0-merror:0.15670	validation_1-merror:0.16126
# [406]	validation_0-merror:0.15668	validation_1-merror:0.16171
# [407]	validation_0-merror:0.15672	validation_1-merror:0.16189
# [408]	validation_0-merror:0.15672	validation_1-merror:0.16171
# [409]	validation_0-merror:0.15672	validation_1-merror:0.16171
# [410]	validation_0-merror:0.15650	validation_1-merror:0.16126
# [411]	validation_0-merror:0.15657	validation_1-merror:0.16144
# [412]	validation_0-merror:0.15639	validation_1-merror:0.16180
# [413]	validation_0-merror:0.15632	validation_1-merror:0.16126
# [414]	validation_0-merror:0.15609	validation_1-merror:0.16126
# [415]	validation_0-merror:0.15621	validation_1-merror:0.16126
# [416]	validation_0-merror:0.15589	validation_1-merror:0.16073
# [417]	validation_0-merror:0.15596	validation_1-merror:0.16082
# [418]	validation_0-merror:0.15580	validation_1-merror:0.16082
# [419]	validation_0-merror:0.15591	validation_1-merror:0.16099
# [420]	validation_0-merror:0.15605	validation_1-merror:0.16117
# [421]	validation_0-merror:0.15603	validation_1-merror:0.16099
# [422]	validation_0-merror:0.15594	validation_1-merror:0.16082
# [423]	validation_0-merror:0.15580	validation_1-merror:0.16082
# [424]	validation_0-merror:0.15605	validation_1-merror:0.16135
# [425]	validation_0-merror:0.15596	validation_1-merror:0.16126
# [426]	validation_0-merror:0.15596	validation_1-merror:0.16109
# [427]	validation_0-merror:0.15621	validation_1-merror:0.16126
# [428]	validation_0-merror:0.15614	validation_1-merror:0.16144
# [429]	validation_0-merror:0.15607	validation_1-merror:0.16126
# ...
# [417]	validation_0-merror:0.13605	validation_1-merror:0.15866
# [418]	validation_0-merror:0.13598	validation_1-merror:0.15866
# [419]	validation_0-merror:0.13594	validation_1-merror:0.15875
# [420]	validation_0-merror:0.13614	validation_1-merror:0.15902
# [421]	validation_0-merror:0.13621	validation_1-merror:0.15875
# [422]	validation_0-merror:0.13614	validation_1-merror:0.15884
# [423]	validation_0-merror:0.13600	validation_1-merror:0.15875
# [424]	validation_0-merror:0.13598	validation_1-merror:0.15884
# [425]	validation_0-merror:0.13598	validation_1-merror:0.15884
# [426]	validation_0-merror:0.13594	validation_1-merror:0.15893
# [427]	validation_0-merror:0.13598	validation_1-merror:0.15875
# [428]	validation_0-merror:0.13592	validation_1-merror:0.15902
# [429]	validation_0-merror:0.13549	validation_1-merror:0.15884
# [430]	validation_0-merror:0.13556	validation_1-merror:0.15893
# [431]	validation_0-merror:0.13544	validation_1-merror:0.15875
# [432]	validation_0-merror:0.13540	validation_1-merror:0.15866
# [433]	validation_0-merror:0.13515	validation_1-merror:0.15875
# [434]	validation_0-merror:0.13522	validation_1-merror:0.15875
# [435]	validation_0-merror:0.13517	validation_1-merror:0.15875
# [436]	validation_0-merror:0.13513	validation_1-merror:0.15884
# [437]	validation_0-merror:0.13495	validation_1-merror:0.15884
# [438]	validation_0-merror:0.13511	validation_1-merror:0.15893
# [439]	validation_0-merror:0.13517	validation_1-merror:0.15893
# [440]	validation_0-merror:0.13513	validation_1-merror:0.15893
# [441]	validation_0-merror:0.13517	validation_1-merror:0.15884
# [442]	validation_0-merror:0.13504	validation_1-merror:0.15884
# [443]	validation_0-merror:0.13499	validation_1-merror:0.15893
# [444]	validation_0-merror:0.13481	validation_1-merror:0.15875
# [445]	validation_0-merror:0.13461	validation_1-merror:0.15866
# [446]	validation_0-merror:0.13441	validation_1-merror:0.15866
# [447]	validation_0-merror:0.13432	validation_1-merror:0.15848
# [448]	validation_0-merror:0.13419	validation_1-merror:0.15884
# [449]	validation_0-merror:0.13410	validation_1-merror:0.15875
# [450]	validation_0-merror:0.13407	validation_1-merror:0.15857
# [451]	validation_0-merror:0.13378	validation_1-merror:0.15857
# [452]	validation_0-merror:0.13362	validation_1-merror:0.15839
# [453]	validation_0-merror:0.13362	validation_1-merror:0.15848
# [454]	validation_0-merror:0.13358	validation_1-merror:0.15857
# [455]	validation_0-merror:0.13349	validation_1-merror:0.15848
# [456]	validation_0-merror:0.13360	validation_1-merror:0.15839
# [457]	validation_0-merror:0.13362	validation_1-merror:0.15830
# [458]	validation_0-merror:0.13365	validation_1-merror:0.15803
# [459]	validation_0-merror:0.13360	validation_1-merror:0.15812
# [460]	validation_0-merror:0.13345	validation_1-merror:0.15839
# [461]	validation_0-merror:0.13336	validation_1-merror:0.15830
# [462]	validation_0-merror:0.13331	validation_1-merror:0.15812
# [463]	validation_0-merror:0.13318	validation_1-merror:0.15803
# [464]	validation_0-merror:0.13309	validation_1-merror:0.15812
# [465]	validation_0-merror:0.13302	validation_1-merror:0.15821
# [466]	validation_0-merror:0.13309	validation_1-merror:0.15803
# [467]	validation_0-merror:0.13311	validation_1-merror:0.15812
# [468]	validation_0-merror:0.13309	validation_1-merror:0.15821
# [469]	validation_0-merror:0.13320	validation_1-merror:0.15821
# [470]	validation_0-merror:0.13318	validation_1-merror:0.15812
# [471]	validation_0-merror:0.13306	validation_1-merror:0.15776
# [472]	validation_0-merror:0.13318	validation_1-merror:0.15776
# [473]	validation_0-merror:0.13306	validation_1-merror:0.15776
# [474]	validation_0-merror:0.13302	validation_1-merror:0.15794
# [475]	validation_0-merror:0.13293	validation_1-merror:0.15803
# [476]	validation_0-merror:0.13291	validation_1-merror:0.15803
# [477]	validation_0-merror:0.13266	validation_1-merror:0.15812
# [478]	validation_0-merror:0.13277	validation_1-merror:0.15812
# [479]	validation_0-merror:0.13284	validation_1-merror:0.15803
# [480]	validation_0-merror:0.13282	validation_1-merror:0.15803
# [481]	validation_0-merror:0.13282	validation_1-merror:0.15794
# [482]	validation_0-merror:0.13268	validation_1-merror:0.15821
# [483]	validation_0-merror:0.13268	validation_1-merror:0.15830
# [484]	validation_0-merror:0.13266	validation_1-merror:0.15848
# [485]	validation_0-merror:0.13275	validation_1-merror:0.15821
# [486]	validation_0-merror:0.13255	validation_1-merror:0.15830
# [487]	validation_0-merror:0.13246	validation_1-merror:0.15812
# [488]	validation_0-merror:0.13239	validation_1-merror:0.15830
# [489]	validation_0-merror:0.13232	validation_1-merror:0.15848
# [490]	validation_0-merror:0.13235	validation_1-merror:0.15839
# [491]	validation_0-merror:0.13226	validation_1-merror:0.15866
# [492]	validation_0-merror:0.13230	validation_1-merror:0.15839
# [493]	validation_0-merror:0.13228	validation_1-merror:0.15830
# [494]	validation_0-merror:0.13212	validation_1-merror:0.15803
# [495]	validation_0-merror:0.13205	validation_1-merror:0.15821
# [496]	validation_0-merror:0.13194	validation_1-merror:0.15803
# [497]	validation_0-merror:0.13196	validation_1-merror:0.15812
# [498]	validation_0-merror:0.13201	validation_1-merror:0.15821
# [499]	validation_0-merror:0.13190	validation_1-merror:0.15812
# [500]	validation_0-merror:0.13183	validation_1-merror:0.15830
# [501]	validation_0-merror:0.13185	validation_1-merror:0.15803
# [502]	validation_0-merror:0.13174	validation_1-merror:0.15830
# [503]	validation_0-merror:0.13174	validation_1-merror:0.15830
# [504]	validation_0-merror:0.13170	validation_1-merror:0.15839
# [505]	validation_0-merror:0.13165	validation_1-merror:0.15776
# [506]	validation_0-merror:0.13172	validation_1-merror:0.15785
# [507]	validation_0-merror:0.13176	validation_1-merror:0.15794
# [508]	validation_0-merror:0.13140	validation_1-merror:0.15749
# [509]	validation_0-merror:0.13138	validation_1-merror:0.15785
# [510]	validation_0-merror:0.13122	validation_1-merror:0.15758
# [511]	validation_0-merror:0.13129	validation_1-merror:0.15767
# [512]	validation_0-merror:0.13111	validation_1-merror:0.15767
# [513]	validation_0-merror:0.13116	validation_1-merror:0.15767
# [514]	validation_0-merror:0.13111	validation_1-merror:0.15749
# [515]	validation_0-merror:0.13095	validation_1-merror:0.15794
# [516]	validation_0-merror:0.13089	validation_1-merror:0.15830
# [517]	validation_0-merror:0.13089	validation_1-merror:0.15821
# [518]	validation_0-merror:0.13064	validation_1-merror:0.15848
# [519]	validation_0-merror:0.13042	validation_1-merror:0.15812
# [520]	validation_0-merror:0.13037	validation_1-merror:0.15812
# [521]	validation_0-merror:0.13028	validation_1-merror:0.15812
# [522]	validation_0-merror:0.13021	validation_1-merror:0.15830
# [523]	validation_0-merror:0.13010	validation_1-merror:0.15821
# [524]	validation_0-merror:0.13026	validation_1-merror:0.15803
# [525]	validation_0-merror:0.13030	validation_1-merror:0.15821
# [526]	validation_0-merror:0.13017	validation_1-merror:0.15794
# [527]	validation_0-merror:0.13017	validation_1-merror:0.15839
# [528]	validation_0-merror:0.13003	validation_1-merror:0.15812
# [529]	validation_0-merror:0.13008	validation_1-merror:0.15794
# [530]	validation_0-merror:0.12994	validation_1-merror:0.15758
# [531]	validation_0-merror:0.12992	validation_1-merror:0.15758
# [532]	validation_0-merror:0.12985	validation_1-merror:0.15767
# [533]	validation_0-merror:0.12979	validation_1-merror:0.15758
# [534]	validation_0-merror:0.12990	validation_1-merror:0.15776
# [535]	validation_0-merror:0.12976	validation_1-merror:0.15776
# [536]	validation_0-merror:0.12972	validation_1-merror:0.15803
# [537]	validation_0-merror:0.12974	validation_1-merror:0.15785
# [538]	validation_0-merror:0.12972	validation_1-merror:0.15794
# [539]	validation_0-merror:0.12976	validation_1-merror:0.15776
# [540]	validation_0-merror:0.12963	validation_1-merror:0.15794
# [541]	validation_0-merror:0.12959	validation_1-merror:0.15758
# [542]	validation_0-merror:0.12945	validation_1-merror:0.15785
# [543]	validation_0-merror:0.12947	validation_1-merror:0.15776
# [544]	validation_0-merror:0.12934	validation_1-merror:0.15794
# [545]	validation_0-merror:0.12940	validation_1-merror:0.15767
# [546]	validation_0-merror:0.12938	validation_1-merror:0.15758
# [547]	validation_0-merror:0.12940	validation_1-merror:0.15758
# [548]	validation_0-merror:0.12920	validation_1-merror:0.15776
# [549]	validation_0-merror:0.12887	validation_1-merror:0.15767
# [550]	validation_0-merror:0.12887	validation_1-merror:0.15785
# [551]	validation_0-merror:0.12882	validation_1-merror:0.15794
# [552]	validation_0-merror:0.12862	validation_1-merror:0.15794
# [553]	validation_0-merror:0.12875	validation_1-merror:0.15803
# [554]	validation_0-merror:0.12871	validation_1-merror:0.15794
# [555]	validation_0-merror:0.12869	validation_1-merror:0.15803
# [556]	validation_0-merror:0.12862	validation_1-merror:0.15803
# [557]	validation_0-merror:0.12866	validation_1-merror:0.15803
# [558]	validation_0-merror:0.12878	validation_1-merror:0.15830
# [559]	validation_0-merror:0.12855	validation_1-merror:0.15848
# [560]	validation_0-merror:0.12873	validation_1-merror:0.15821
# [561]	validation_0-merror:0.12871	validation_1-merror:0.15839
# [562]	validation_0-merror:0.12860	validation_1-merror:0.15812
# [563]	validation_0-merror:0.12860	validation_1-merror:0.15812
# [564]	validation_0-merror:0.12848	validation_1-merror:0.15821
# [565]	validation_0-merror:0.12855	validation_1-merror:0.15803
# [566]	validation_0-merror:0.12855	validation_1-merror:0.15785
# [567]	validation_0-merror:0.12817	validation_1-merror:0.15767
# [568]	validation_0-merror:0.12821	validation_1-merror:0.15767
# [569]	validation_0-merror:0.12813	validation_1-merror:0.15776
# [570]	validation_0-merror:0.12806	validation_1-merror:0.15776
# [571]	validation_0-merror:0.12810	validation_1-merror:0.15794
# [572]	validation_0-merror:0.12801	validation_1-merror:0.15776
# [573]	validation_0-merror:0.12795	validation_1-merror:0.15803
# [574]	validation_0-merror:0.12795	validation_1-merror:0.15776
# [575]	validation_0-merror:0.12788	validation_1-merror:0.15839
# [576]	validation_0-merror:0.12777	validation_1-merror:0.15839
# [577]	validation_0-merror:0.12779	validation_1-merror:0.15830
# [578]	validation_0-merror:0.12763	validation_1-merror:0.15839
# [579]	validation_0-merror:0.12754	validation_1-merror:0.15830
# [580]	validation_0-merror:0.12745	validation_1-merror:0.15812
# [581]	validation_0-merror:0.12750	validation_1-merror:0.15830
# [582]	validation_0-merror:0.12752	validation_1-merror:0.15776
# [583]	validation_0-merror:0.12748	validation_1-merror:0.15749
# [584]	validation_0-merror:0.12748	validation_1-merror:0.15767
# [585]	validation_0-merror:0.12743	validation_1-merror:0.15767
# [586]	validation_0-merror:0.12743	validation_1-merror:0.15785
# [587]	validation_0-merror:0.12727	validation_1-merror:0.15830
# [588]	validation_0-merror:0.12723	validation_1-merror:0.15821
# [589]	validation_0-merror:0.12721	validation_1-merror:0.15812
# [590]	validation_0-merror:0.12723	validation_1-merror:0.15821
# [591]	validation_0-merror:0.12727	validation_1-merror:0.15830
# [592]	validation_0-merror:0.12721	validation_1-merror:0.15821
# [593]	validation_0-merror:0.12725	validation_1-merror:0.15812
# [594]	validation_0-merror:0.12709	validation_1-merror:0.15803
# [595]	validation_0-merror:0.12716	validation_1-merror:0.15794
# [596]	validation_0-merror:0.12718	validation_1-merror:0.15794
# [597]	validation_0-merror:0.12712	validation_1-merror:0.15812
# [598]	validation_0-merror:0.12703	validation_1-merror:0.15785
# [599]	validation_0-merror:0.12689	validation_1-merror:0.15758
# [600]	validation_0-merror:0.12696	validation_1-merror:0.15767
# [601]	validation_0-merror:0.12698	validation_1-merror:0.15767
# [602]	validation_0-merror:0.12671	validation_1-merror:0.15767
# [603]	validation_0-merror:0.12671	validation_1-merror:0.15776
#   3%|▎         | 3/100 [02:09<1:16:09, 47.11s/trial, best loss: -0.8327946127946128]

# %%
print("The best hyperparameters are: ", "\n")
print(best_hyperparams)

# %%
xgb = XGBClassifier(use_label_encoder=False,
                    eval_metric= 'mlogloss',
                    objective= 'multi:softmax',
                    tree_method='gpu_hist',
                    booster= 'gbtree',
                    silent= 1,
                    seed= 42,
                    num_class= 3,
                    sample_weight=sample_weights,
                    colsample_bytree=0.7,
                    eta=0.075,
                    gamma=0.65,
                    max_depth=6,
                    mind_child_weight=6,
                    n_estimators=166,
                    subsample=0.75
                    )

watchlist = [(X_train_, y_train_), (X_val, y_val)]

xgb.fit(X_train_, y_train_, eval_set=watchlist)
y_hat_train = xgb.predict(X_train_)
y_hat = xgb.predict(X_test_)
#
# y_hat = clf.predict(X_test)
print('Train Accuracy score:', accuracy_score(y_hat_train, y_train_))
# # print('Accuracy score:', accuracy_score(y_test, y_hat))
print('Test Accuracy Score:', accuracy_score(y_test_, y_hat))

# %%
test_df_ = test_df[[col for col in X.columns]]
pred = pd.DataFrame(le.inverse_transform(xgb.predict(test_df_)), columns=['status_group'])
sub_idx = pd.DataFrame(pd.read_csv(test_url)['id'])
sub_idx.reset_index(drop=True, inplace=True)
final_sub = pd.concat([sub_idx, pred], axis=1)
final_sub.reset_index(drop=True, inplace=True)
final_sub.set_index('id').to_csv('data/final_sub.csv')
